# %% [markdown]
# <a href="https://colab.research.google.com/github/aqshaparker/Pemrograman-Dasar/blob/main/praktikum%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("--- Soal 1 ---")
# Mencetak bilangan ganjil 1 hingga 9
for angka in range(1, 10, 2):
    print(angka)
# Out:
# --- Soal 1 ---
# 1
# 3
# 5
# 7
# 9

# %%
print("--- Soal 2 ---")
kode_berhenti = 99
input_pengguna = 0 # Inisialisasi awal

while input_pengguna != kode_berhenti:
    try:
        input_pengguna = int(input("Masukkan angka (99 untuk berhenti): "))
    except ValueError:
        print("Input tidak valid. Harap masukkan angka.")

print("Perulangan telah dihentikan oleh sentinel (99).")
# Out:
# --- Soal 2 ---
# Masukkan angka (99 untuk berhenti): 1
# Masukkan angka (99 untuk berhenti): 2
# Masukkan angka (99 untuk berhenti): 3
# Masukkan angka (99 untuk berhenti): 99
# Perulangan telah dihentikan oleh sentinel (99).

# %%
print("--- Soal 3 ---")
harga_barang = [15000, 25000, 10000, 5000]
total_belanja = 0

for harga in harga_barang:
    total_belanja += harga

print("Total biaya belanja adalah:", total_belanja)
# Out:
# --- Soal 3 ---
# Total biaya belanja adalah: 55000

# %%
print("--- Soal 4 ---")
percobaan_maksimal = 3
percobaan_saat_ini = 1

while percobaan_saat_ini <= percobaan_maksimal:
    print(f"Percobaan ke-{percobaan_saat_ini}...")
    # Asumsi ada logika input password di sini
    percobaan_saat_ini += 1

if percobaan_saat_ini == percobaan_maksimal + 1:
    print("Kesempatan habis.")
else:
    print("Akses diterima.")
# Out:
# --- Soal 4 ---
# Percobaan ke-1...
# Percobaan ke-2...
# Percobaan ke-3...
# Kesempatan habis.

# %%
print("--- Soal 5 ---")
nama_proyek = "PRAKTIKUM"
hasil_output = ""

for karakter in nama_proyek:
    hasil_output += karakter + "-"

print(hasil_output) # Output: P-R-A-K-T-I-K-U-M-
# Out:
# --- Soal 5 ---
# P-R-A-K-T-I-K-U-M-

# %%
print("--- Soal 6 ---")
# Countdown dari 5 ke 1
for i in range(5, 0, -1):
    print(i)
# Out:
# --- Soal 6 ---
# 5
# 4
# 3
# 2
# 1

# %%
print("--- Soal 7 ---")
bulan = ["Januari", "Februari", "Maret", "April", "Mei", "Juni", "Juli", "Agustus"]

for index, item in enumerate(bulan):
    print(f"Bulan ke-{index + 1}: {item}")
# Out:
# --- Soal 7 ---
# Bulan ke-1: Januari
# Bulan ke-2: Februari
# Bulan ke-3: Maret
# Bulan ke-4: April
# Bulan ke-5: Mei
# Bulan ke-6: Juni
# Bulan ke-7: Juli
# Bulan ke-8: Agustus

# %%
print("--- Soal 8 ---")
data_angka = [10, 20, 30, -1, 50, 60]

for angka in data_angka:
    if angka == -1:
        break
    print(angka)

print("Program berhenti karena angka -1 ditemukan.")
# Out:
# --- Soal 8 ---
# 10
# 20
# 30
# Program berhenti karena angka -1 ditemukan.

# %%
print("--- Soal 9 ---")
total = 0
bilangan = 1
batas = 20

while total <= batas:
    total += bilangan
    bilangan += 1

print("Total terakhir:", total)
# Out:
# --- Soal 9 ---
# Total terakhir: 21

# %%
print("--- Soal 10 ---")
jumlah_baris = 3

for baris in range(jumlah_baris):
    baris_teks = ""
    for baris in range(0,1):
        baris_teks += "Python "
    print(baris_teks)
# Out:
# --- Soal 10 ---
# Python
# Python
# Python
